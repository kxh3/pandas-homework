# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns 

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
csvpath = Path('C:/Users/krist/OneDrive/Desktop/UPENN-VIRT-FIN-PT-01-2022-U-LOL/02-Homework/04-Pandas/Instructions/Starter_Code/Resources/whale_returns.csv')
whale_df = pd.read_csv(csvpath, parse_dates=True, infer_datetime_format=True)
whale_df
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     2015-03-02                        NaN                 NaN
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                             NaN                     NaN
# 1                       -0.000496               -0.006569
# ...

# %%
whale_df['Date'] = pd.to_datetime(whale_df['Date'], dayfirst=True)

# %%
# Date should not be treated as data so set to index
whale_df = whale_df.set_index('Date')
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df = whale_df.dropna()
whale_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_file = Path('C:/Users/krist/OneDrive/Desktop/UPENN-VIRT-FIN-PT-01-2022-U-LOL/02-Homework/04-Pandas/Instructions/Starter_Code/Resources/algo_returns.csv')
algo_df = pd.read_csv(algo_file, parse_dates=True, infer_datetime_format=True)
algo_df
# Out:
#             Date    Algo 1    Algo 2
# 0     2014-05-28  0.001745       NaN
# 1     2014-05-29  0.003978       NaN
# 2     2014-05-30  0.004464       NaN
# 3     2014-06-02  0.005692       NaN
# 4     2014-06-03  0.005292       NaN
# ...          ...       ...       ...
# 1236  2019-04-25  0.000682 -0.007247
# 1237  2019-04-26  0.002981  0.005256
# 1238  2019-04-29  0.005208  0.002829
# 1239  2019-04-30 -0.002944 -0.001570
# 1240  2019-05-01  0.000094 -0.007358
#
# [1241 rows x 3 columns]

# %%
algo_df['Date'] = pd.to_datetime(algo_df['Date'], dayfirst=True)

# %%
# Again date should not be counted as data so we set to index
algo_df = algo_df.set_index('Date')
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df = algo_df.dropna()
algo_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp_path = Path('C:/Users/krist/OneDrive/Desktop/UPENN-VIRT-FIN-PT-01-2022-U-LOL/02-Homework/04-Pandas/Instructions/Starter_Code/Resources/sp500_history.csv')
sp_df = pd.read_csv(sp_path, parse_dates=True, infer_datetime_format=True)
sp_df
# Out:
#            Date     Close
# 0     23-Apr-19  $2933.68
# 1     22-Apr-19  $2907.97
# 2     18-Apr-19  $2905.03
# 3     17-Apr-19  $2900.45
# 4     16-Apr-19  $2907.06
# ...         ...       ...
# 1644   5-Oct-12  $1460.93
# 1645   4-Oct-12  $1461.40
# 1646   3-Oct-12  $1450.99
# 1647   2-Oct-12  $1445.75
# 1648   1-Oct-12  $1444.49
#
# [1649 rows x 2 columns]

# %%
# Check Data Types
sp_df.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
# Set to date time format 
sp_df['Date'] = pd.to_datetime(sp_df['Date'], dayfirst=True)

# %%
# Set date as index
sp_df = sp_df.set_index("Date")
sp_df
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06
# ...              ...
# 2012-10-05  $1460.93
# 2012-10-04  $1461.40
# 2012-10-03  $1450.99
# 2012-10-02  $1445.75
# 2012-10-01  $1444.49
#
# [1649 rows x 1 columns]

# %%
# Fix Data Types
sp_df = sp_df.astype(str)
sp_df['Close'] = sp_df['Close'].str.replace('$', '', regex=True).astype(float)
sp_df['Close'].dtype
# Out:
# dtype('float64')

# %%
sp_df
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06
# ...             ...
# 2012-10-05  1460.93
# 2012-10-04  1461.40
# 2012-10-03  1450.99
# 2012-10-02  1445.75
# 2012-10-01  1444.49
#
# [1649 rows x 1 columns]

# %%
# Calculate Daily Returns
sp_returns = sp_df.pct_change()
sp_returns
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1649 rows x 1 columns]

# %%
# Drop nulls
sp_returns = sp_returns.dropna()
sp_returns
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_returns = sp_returns.rename(columns={"Close":"S&P 500"})

# %%
sp_returns
# Out:
#              S&P 500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_portfolio = pd.concat([whale_df, algo_df, sp_returns], axis='columns', join='inner')
combined_portfolio
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_portfolio.plot(figsize=(20,10), title='Daily Returns')
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
combined_portfolio_returns = (1 + combined_portfolio).cumprod()
combined_portfolio_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# 2015-03-06                     0.990844                0.991172  0.983641
# 2015-03-09                     0.996633                0.989534  0.978283
#
#               Algo 2   S&P 500
# Date
# 2015-03-03  0.999051  1.004408
# 2015-03-04  1.001464  1.003208
# 2015-03-05  1.005794  1.017632
# ...

# %%
# Plot cumulative returns
combined_portfolio_returns.plot(figsize = (20,10), title = 'Cumulative Returns')
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_portfolio.plot.box(figsize=(20,10), title= 'Risk Data')
# Out:
# <AxesSubplot:title={'center':'Risk Data'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_std = combined_portfolio.std()
daily_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# S&P 500                        0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp_std = daily_std['S&P 500']
# Determine which portfolios are riskier than the S&P 500
risky_portfolios = [daily_std > sp_std]
risky_portfolios
# Out:
# [SOROS FUND MANAGEMENT LLC      False
#  PAULSON & CO.INC.              False
#  TIGER GLOBAL MANAGEMENT LLC     True
#  BERKSHIRE HATHAWAY INC          True
#  Algo 1                         False
#  Algo 2                         False
#  S&P 500                        False
#  dtype: bool]

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std *np.sqrt(252)
annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# S&P 500                        0.136313
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_portfolio_rolling = combined_portfolio.rolling(window=21).std()
# Plot the rolling standard deviation
combined_portfolio_rolling.plot(figsize = (20,10), title='Rolling STD')
# Out:
# <AxesSubplot:title={'center':'Rolling STD'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = combined_portfolio.corr()
# Display de correlation matrix
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# S&P 500                                       0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
algo_1_cov = combined_portfolio['Algo 1'].rolling(window=60).cov()
algo_1_cov
# Calculate variance of S&P 500
sp_var = combined_portfolio['S&P 500'].rolling(window=60).var()
sp_var
# Computing beta
portfolio_beta = algo_1_cov / sp_var
# Plot beta trend
beta_plot = portfolio_beta.plot(figsize=(20,10), title='Beta Data')

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
rolling_ewm = combined_portfolio.ewm(halflife=21, adjust=20).std()
rolling_ewm
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.002677            0.004968
# 2015-03-06                   0.005349            0.004615
# 2015-03-09                   0.004638            0.004471
# ...                               ...                 ...
# 2019-04-15                   0.007755            0.006960
# 2019-04-16                   0.007632            0.006846
# 2019-04-17                   0.007547            0.006846
# 2019-04-18                   0.007424            0.006737
# 2019-04-22                   0.007336            0.006764
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                     0.001441                0.007624  0.004700
# ...

# %%
rolling_ewm.plot(figsize = (20,10), title='Rolling Data')
# Out:
# <AxesSubplot:title={'center':'Rolling Data'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharp_ratios = (combined_portfolio.mean() * 252) / (combined_portfolio.std() *np.sqrt(252))
sharp_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# S&P 500                       -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharp_ratios.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!
#
# Algorithm 1 outperformed both the market and whale portfolios based on certain observations. First of all algo 1 has the highest sharpe ratio compared to the rest, going over the 1.0 mark. As stated previously, the higher the sharpe ratio, the better returns there are with lower risk. Secondly, over the years its beta number mostly remained over 1, even reached 3 at one point. This indicates that it is more volatile than the overall market. Therefore, when the market moves up, so will algo 1, but at a much greater pace. A third observation is that its standard deviation was very low indicating its prices do not see drastic, unpredictable changes, so there is low risk here.
# Meanwhile, Algorithm 2 did not do as great. It appears that algo 2 was played more safely since it did have a low standard deviation/risk, and did not produce huge returns. As seen in its low sharpe ratio number.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
msft_path = Path('C:/Users/krist/OneDrive/Desktop/UPENN-VIRT-FIN-PT-01-2022-U-LOL/02-Homework/04-Pandas/Instructions/Starter_Code/Resources/msft.csv')
msft_df = pd.read_csv(msft_path, parse_dates=True, infer_datetime_format=True)
msft_df
# Out:
#                     Date   Close
# 0      3/2/2015 16:00:00   43.88
# 1      3/3/2015 16:00:00   43.28
# 2      3/4/2015 16:00:00   43.06
# 3      3/5/2015 16:00:00   43.11
# 4      3/6/2015 16:00:00   42.36
# ...                  ...     ...
# 1757  2/18/2022 16:00:00  287.93
# 1758  2/22/2022 16:00:00  287.72
# 1759  2/23/2022 16:00:00  280.27
# 1760  2/24/2022 16:00:00  294.59
# 1761  2/25/2022 16:00:00  297.31
#
# [1762 rows x 2 columns]

# %%
# Set to date time format 
msft_df['Date'] = pd.to_datetime(msft_df['Date'])

# %%
# Set date as index
msft_df = msft_df.set_index('Date')

# %%
#Get rid of the time in date column 
msft_df.index = msft_df.index.date

# %%
msft_df
# Out:
#              Close
# 2015-03-02   43.88
# 2015-03-03   43.28
# 2015-03-04   43.06
# 2015-03-05   43.11
# 2015-03-06   42.36
# ...            ...
# 2022-02-18  287.93
# 2022-02-22  287.72
# 2022-02-23  280.27
# 2022-02-24  294.59
# 2022-02-25  297.31
#
# [1762 rows x 1 columns]

# %%
# Reading data from 2nd stock
amzn_path = Path('C:/Users/krist/OneDrive/Desktop/UPENN-VIRT-FIN-PT-01-2022-U-LOL/02-Homework/04-Pandas/Instructions/Starter_Code/Resources/amzn.csv')
amzn_df = pd.read_csv(amzn_path, parse_dates=True, infer_datetime_format=True)
amzn_df
# Out:
#                     Date    Close
# 0      3/2/2015 16:00:00   385.66
# 1      3/3/2015 16:00:00   384.61
# 2      3/4/2015 16:00:00   382.72
# 3      3/5/2015 16:00:00   387.83
# 4      3/6/2015 16:00:00   380.09
# ...                  ...      ...
# 1757  2/18/2022 16:00:00  3052.03
# 1758  2/22/2022 16:00:00  3003.95
# 1759  2/23/2022 16:00:00  2896.54
# 1760  2/24/2022 16:00:00  3027.16
# 1761  2/25/2022 16:00:00  3075.77
#
# [1762 rows x 2 columns]

# %%
# Set to date time format
amzn_df['Date'] = pd.to_datetime(amzn_df['Date'])

# %%
# Set date as index
amzn_df = amzn_df.set_index('Date')

# %%
# Get rid of time in date column
amzn_df.index = amzn_df.index.date

# %%
amzn_df
# Out:
#               Close
# 2015-03-02   385.66
# 2015-03-03   384.61
# 2015-03-04   382.72
# 2015-03-05   387.83
# 2015-03-06   380.09
# ...             ...
# 2022-02-18  3052.03
# 2022-02-22  3003.95
# 2022-02-23  2896.54
# 2022-02-24  3027.16
# 2022-02-25  3075.77
#
# [1762 rows x 1 columns]

# %%
# Reading data from 3rd stock
tsla_path = Path('C:/Users/krist/OneDrive/Desktop/UPENN-VIRT-FIN-PT-01-2022-U-LOL/02-Homework/04-Pandas/Instructions/Starter_Code/Resources/tsla.csv')
tsla_df = pd.read_csv(tsla_path, parse_dates=True, infer_datetime_format=True)
tsla_df
# Out:
#                     Date   Close
# 0      3/2/2015 16:00:00   39.47
# 1      3/3/2015 16:00:00   39.91
# 2      3/4/2015 16:00:00   40.49
# 3      3/5/2015 16:00:00   40.13
# 4      3/6/2015 16:00:00   38.78
# ...                  ...     ...
# 1757  2/18/2022 16:00:00  856.98
# 1758  2/22/2022 16:00:00  821.53
# 1759  2/23/2022 16:00:00  764.04
# 1760  2/24/2022 16:00:00  800.77
# 1761  2/25/2022 16:00:00  809.87
#
# [1762 rows x 2 columns]

# %%
# Set to date time format
tsla_df['Date'] = pd.to_datetime(tsla_df['Date'])

# %%
# Set date as index
tsla_df = tsla_df.set_index('Date')

# %%
# Get rid of time in date column
tsla_df.index = tsla_df.index.date

# %%
tsla_df
# Out:
#              Close
# 2015-03-02   39.47
# 2015-03-03   39.91
# 2015-03-04   40.49
# 2015-03-05   40.13
# 2015-03-06   38.78
# ...            ...
# 2022-02-18  856.98
# 2022-02-22  821.53
# 2022-02-23  764.04
# 2022-02-24  800.77
# 2022-02-25  809.87
#
# [1762 rows x 1 columns]

# %%
# Combine all stocks in a single DataFrame
combined_stocks = pd.concat([msft_df, amzn_df, tsla_df], axis= 'columns', join='inner')
combined_stocks
# Out:
#              Close    Close   Close
# 2015-03-02   43.88   385.66   39.47
# 2015-03-03   43.28   384.61   39.91
# 2015-03-04   43.06   382.72   40.49
# 2015-03-05   43.11   387.83   40.13
# 2015-03-06   42.36   380.09   38.78
# ...            ...      ...     ...
# 2022-02-18  287.93  3052.03  856.98
# 2022-02-22  287.72  3003.95  821.53
# 2022-02-23  280.27  2896.54  764.04
# 2022-02-24  294.59  3027.16  800.77
# 2022-02-25  297.31  3075.77  809.87
#
# [1762 rows x 3 columns]

# %%
# Reset Date index
combined_stocks.sort_index(inplace=True)

# %%
# Reorganize portfolio data by having a column per symbol
combined_stocks.columns = ['MSFT', 'AMZN', 'TSLA']

# %%
combined_stocks.head()
# Out:
#              MSFT    AMZN   TSLA
# 2015-03-02  43.88  385.66  39.47
# 2015-03-03  43.28  384.61  39.91
# 2015-03-04  43.06  382.72  40.49
# 2015-03-05  43.11  387.83  40.13
# 2015-03-06  42.36  380.09  38.78

# %%
combined_stocks.dtypes
# Out:
# MSFT    float64
# AMZN    float64
# TSLA    float64
# dtype: object

# %%
# Calculate daily returns
combined_stocks = combined_stocks.pct_change()
# Drop NAs
combined_stocks = combined_stocks.dropna()
# Display sample data
combined_stocks
# Out:
#                 MSFT      AMZN      TSLA
# 2015-03-03 -0.013674 -0.002723  0.011148
# 2015-03-04 -0.005083 -0.004914  0.014533
# 2015-03-05  0.001161  0.013352 -0.008891
# 2015-03-06 -0.017397 -0.019957 -0.033641
# 2015-03-09  0.011568 -0.004025 -0.015472
# ...              ...       ...       ...
# 2022-02-18 -0.009631 -0.013262 -0.022103
# 2022-02-22 -0.000729 -0.015753 -0.041366
# 2022-02-23 -0.025893 -0.035756 -0.069979
# 2022-02-24  0.051094  0.045095  0.048073
# 2022-02-25  0.009233  0.016058  0.011364
#
# [1761 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
combined_stocks_weighted = combined_stocks.dot(weights)
# Display sample data
combined_stocks_weighted.head()
# Out:
# 2015-03-03   -0.001750
# 2015-03-04    0.001512
# 2015-03-05    0.001874
# 2015-03-06   -0.023665
# 2015-03-09   -0.002643
# dtype: float64

# %%
# Give weighted return column a name
combined_stocks_weighted = combined_stocks_weighted.rename("My Returns")
combined_stocks_weighted.head()
# Out:
# 2015-03-03   -0.001750
# 2015-03-04    0.001512
# 2015-03-05    0.001874
# 2015-03-06   -0.023665
# 2015-03-09   -0.002643
# Name: My Returns, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
new_combined_portfolios = pd.concat([whale_df, algo_df, sp_returns, combined_stocks_weighted], axis='columns', join='inner')
new_combined_portfolios
# Out:
# C:\Users\krist\anaconda3\lib\site-packages\pandas\core\indexes\base.py:334: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   joined_ndarray, lidx, ridx = libjoin.inner_join_indexer(sv, ov)
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# ...

# %%
# Calculates portfolio std in order to make comparisons in the next cell
new_daily_stds = new_combined_portfolios.std()
new_daily_stds
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# S&P 500                        0.008587
# My Returns                     0.016070
# dtype: float64

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
new_risky_portfolios = [new_daily_stds > new_daily_stds['S&P 500']]
for values in new_risky_portfolios:
    values.dropna(inplace=True)
new_risky_portfolios
# Out:
# [SOROS FUND MANAGEMENT LLC      False
#  PAULSON & CO.INC.              False
#  TIGER GLOBAL MANAGEMENT LLC     True
#  BERKSHIRE HATHAWAY INC          True
#  Algo 1                         False
#  Algo 2                         False
#  S&P 500                        False
#  My Returns                      True
#  dtype: bool]

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
new_combined_portfolios_ann_std = new_daily_stds *np.sqrt(252)
new_combined_portfolios_ann_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# S&P 500                        0.136313
# My Returns                     0.255107
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
new_combined_portfolios.rolling(window=21).std().plot(figsize=(20,10), title='Rolling STD')
# Plot rolling standard deviation
# Out:
# <AxesSubplot:title={'center':'Rolling STD'}>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
new_combined_portfolios_corr = new_combined_portfolios.corr()
new_combined_portfolios_corr
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# S&P 500                                       0.000574            0.013549
# My Returns                                    0.605351            0.450464
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# ...

# %%
# Plot correlation
sns.heatmap(new_combined_portfolios_corr, vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
my_returns_cov = new_combined_portfolios['My Returns'].rolling(window=60).cov(new_combined_portfolios['S&P 500'])
my_returns_cov
# Out:
# 2015-03-03             NaN
# 2015-03-04             NaN
# 2015-03-05             NaN
# 2015-03-06             NaN
# 2015-03-09             NaN
#                   ...
# 2019-04-15   -1.256471e-05
# 2019-04-16   -1.653012e-06
# 2019-04-17   -1.896349e-06
# 2019-04-18   -1.816602e-06
# 2019-04-22   -2.458650e-07
# Length: 1042, dtype: float64

# %%
all_returns_var = new_combined_portfolios['S&P 500'].rolling(window=60).var()
all_returns_var
# Out:
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-15    0.000041
# 2019-04-16    0.000037
# 2019-04-17    0.000037
# 2019-04-18    0.000037
# 2019-04-22    0.000037
# Name: S&P 500, Length: 1042, dtype: float64

# %%
returns_beta = my_returns_cov / all_returns_var
returns_beta
# Out:
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-15   -0.304825
# 2019-04-16   -0.044435
# 2019-04-17   -0.050985
# 2019-04-18   -0.048834
# 2019-04-22   -0.006595
# Length: 1042, dtype: float64

# %%
returns_beta.plot(figsize=(20,10), title ='Rolling 60-Day Variance of My Returns vs. S&P Returns')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Variance of My Returns vs. S&P Returns'}>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
new_combined_portfolios_sharp_ratios = (new_combined_portfolios.mean() * 252) / (new_combined_portfolios.std()* np.sqrt(252))
new_combined_portfolios_sharp_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# S&P 500                       -0.518582
# My Returns                     1.142674
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
new_combined_portfolios_sharp_ratios.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
#
# My portfolio appears to have produced a great amount of returns over the years. When compared to the others, it has the second highest sharpe ratio coming after algorithm 1. As seen in the rolling beta chart, my portfolio reached high beta numbers indicating that it moved quicker than the market itself. Though over the more recent years it decreased, and the prices are moving at a slower, calm pace. This simply means that my portfolio contains stocks that are good for the long run since they move slowly. Its rolling standard deviation is higher than the rest, but the value itself stays below 0.035 over the years, which is low and safe. Overall, I believe my portfolio is great for someone who is investing long term, and want less risk.
